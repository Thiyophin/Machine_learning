# %%
import os
import pandas as pd

# %%
for dirname, _, filenames in os.walk('data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# data/train.csv
# data/test.csv
# data/stores.csv
# data/features.csv

# %%
df_train = pd.read_csv('data/train.csv')

# %%
df_train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
len(df_train)
# Out:
# 421570

# %%
df_test = pd.read_csv('data/test.csv')

# %%
df_test.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
len(df_test)
# Out:
# 115064

# %%
df_train.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
df_stores = pd.read_csv('data/stores.csv')

# %%
df_features = pd.read_csv('data/features.csv')

# %%
df_stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
len(df_stores)
# Out:
# 45

# %%
df_stores.tail()
# Out:
#     Store Type    Size
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221

# %%
df_features = pd.read_csv('data/features.csv')

# %%
df_features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
len(df_features)
# Out:
# 8190

# %%
df_features.tail()
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5  CPI  Unemployment  IsHoliday
# 8185       3.00    2449.97    3169.69  NaN           NaN      False
# 8186     582.74    5797.47    1514.93  NaN           NaN      False
# 8187      85.72     744.84    2150.36  NaN           NaN      False
# 8188     204.19     363.00    1059.46  NaN           NaN      False
# 8189       2.06      10.88    1864.57  NaN           NaN      False

# %% [markdown]
# # Data preparation and analysis

# %% [markdown]
# Merging the features and training data to get cumulative insights from overall

# %%
traindf1 = df_train.merge(df_features,how='left',indicator=True).merge(df_stores,how='left') # merging allthree dataframes with matching store column

# %%
traindf1.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1  2010-02-05      24924.50      False        42.31       2.572
# 1      1     1  2010-02-12      46039.49       True        38.51       2.548
# 2      1     1  2010-02-19      41595.55      False        39.93       2.514
# 3      1     1  2010-02-26      19403.54      False        46.63       2.561
# 4      1     1  2010-03-05      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment _merge Type    Size
# 0         8.106   both    A  151315
# 1         8.106   both    A  151315
# 2         8.106   both    A  151315
# 3         8.106   both    A  151315
# 4         8.106   both    A  151315

# %%
traindf1.tail()
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 421565     45    98  2012-09-28        508.37      False        64.88
# 421566     45    98  2012-10-05        628.10      False        64.89
# 421567     45    98  2012-10-12       1061.02      False        54.47
# 421568     45    98  2012-10-19        760.01      False        56.47
# 421569     45    98  2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 421565       3.997    4556.61      20.64       1.50    1601.01    3288.25
# 421566       3.985    5046.74        NaN      18.82    2253.43    2340.01
# 421567       4.000    1956.28        NaN       7.89     599.32    3990.54
# 421568       3.969    2004.02        NaN       3.18     437.73    1537.49
# 421569       3.882    4018.91      58.08     100.00     211.94     858.33
#
#                CPI  Unemployment _merge Type    Size
# 421565  192.013558         8.684   both    B  118221
# 421566  192.170412         8.667   both    B  118221
# 421567  192.327265         8.667   both    B  118221
# 421568  192.330854         8.667   both    B  118221
# 421569  192.308899         8.667   both    B  118221

# %%
traindf1
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50      False        42.31
# 1           1     1  2010-02-12      46039.49       True        38.51
# 2           1     1  2010-02-19      41595.55      False        39.93
# 3           1     1  2010-02-26      19403.54      False        46.63
# 4           1     1  2010-03-05      21827.90      False        46.50
# ...       ...   ...         ...           ...        ...          ...
# 421565     45    98  2012-09-28        508.37      False        64.88
# 421566     45    98  2012-10-05        628.10      False        64.89
# 421567     45    98  2012-10-12       1061.02      False        54.47
# 421568     45    98  2012-10-19        760.01      False        56.47
# 421569     45    98  2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0            2.572        NaN        NaN        NaN        NaN        NaN
# 1            2.548        NaN        NaN        NaN        NaN        NaN
# 2            2.514        NaN        NaN        NaN        NaN        NaN
# 3            2.561        NaN        NaN        NaN        NaN        NaN
# 4            2.625        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 421565       3.997    4556.61      20.64       1.50    1601.01    3288.25
# 421566       3.985    5046.74        NaN      18.82    2253.43    2340.01
# 421567       4.000    1956.28        NaN       7.89     599.32    3990.54
# 421568       3.969    2004.02        NaN       3.18     437.73    1537.49
# 421569       3.882    4018.91      58.08     100.00     211.94     858.33
#
#                CPI  Unemployment _merge Type    Size
# 0       211.096358         8.106   both    A  151315
# 1       211.242170         8.106   both    A  151315
# 2       211.289143         8.106   both    A  151315
# 3       211.319643         8.106   both    A  151315
# 4       211.350143         8.106   both    A  151315
# ...            ...           ...    ...  ...     ...
# 421565  192.013558         8.684   both    B  118221
# 421566  192.170412         8.667   both    B  118221
# 421567  192.327265         8.667   both    B  118221
# 421568  192.330854         8.667   both    B  118221
# 421569  192.308899         8.667   both    B  118221
#
# [421570 rows x 17 columns]

# %%
traindf2 = traindf1.drop(['MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5'],axis=1) # axis = 0 deletes Nan valued rows , axis=1 delete Nan valued Column

# %%
traindf2
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50      False        42.31
# 1           1     1  2010-02-12      46039.49       True        38.51
# 2           1     1  2010-02-19      41595.55      False        39.93
# 3           1     1  2010-02-26      19403.54      False        46.63
# 4           1     1  2010-03-05      21827.90      False        46.50
# ...       ...   ...         ...           ...        ...          ...
# 421565     45    98  2012-09-28        508.37      False        64.88
# 421566     45    98  2012-10-05        628.10      False        64.89
# 421567     45    98  2012-10-12       1061.02      False        54.47
# 421568     45    98  2012-10-19        760.01      False        56.47
# 421569     45    98  2012-10-26       1076.80      False        58.85
#
#         Fuel_Price         CPI  Unemployment _merge Type    Size
# 0            2.572  211.096358         8.106   both    A  151315
# 1            2.548  211.242170         8.106   both    A  151315
# 2            2.514  211.289143         8.106   both    A  151315
# 3            2.561  211.319643         8.106   both    A  151315
# 4            2.625  211.350143         8.106   both    A  151315
# ...            ...         ...           ...    ...  ...     ...
# 421565       3.997  192.013558         8.684   both    B  118221
# 421566       3.985  192.170412         8.667   both    B  118221
# 421567       4.000  192.327265         8.667   both    B  118221
# 421568       3.969  192.330854         8.667   both    B  118221
# 421569       3.882  192.308899         8.667   both    B  118221
#
# [421570 rows x 12 columns]

# %%
# lets check the missing data values
traindf2.isna().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# _merge          0
# Type            0
# Size            0
# dtype: int64

# %%
# now lets see how many negative and zero sales values are there
traindf2.loc[traindf2['Weekly_Sales']<=0] # outliers
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 846         1     6  2012-08-10       -139.65      False        85.05
# 2384        1    18  2012-05-04         -1.27      False        75.55
# 6048        1    47  2010-02-19       -863.00      False        39.93
# 6049        1    47  2010-03-12       -698.00      False        57.79
# 6051        1    47  2010-10-08        -58.00      False        63.93
# ...       ...   ...         ...           ...        ...          ...
# 419597     45    80  2010-02-12         -0.43       True        27.73
# 419598     45    80  2010-02-19         -0.27      False        31.27
# 419603     45    80  2010-04-16         -1.61      False        54.28
# 419614     45    80  2010-07-02         -0.27      False        76.61
# 419640     45    80  2011-02-11         -0.24       True        30.30
#
#         Fuel_Price         CPI  Unemployment _merge Type    Size
# 846          3.494  221.958433         6.908   both    A  151315
# 2384         3.749  221.671800         7.143   both    A  151315
# 6048         2.514  211.289143         8.106   both    A  151315
# 6049         2.667  211.380643         8.106   both    A  151315
# 6051         2.633  211.746754         7.838   both    A  151315
# ...            ...         ...           ...    ...  ...     ...
# 419597       2.773  181.982317         8.992   both    B  118221
# 419598       2.745  182.034782         8.992   both    B  118221
# 419603       2.899  181.692477         8.899   both    B  118221
# 419614       2.815  182.318780         8.743   both    B  118221
# 419640       3.239  183.701613         8.549   both    B  118221
#
# [1358 rows x 12 columns]

# %% [markdown]
# # lets remove these data,
#   -  Negative and zero sales values might represent errors or outliers, and keeping them in the dataset could lead to misleading conclusions.
#   -  Removing these values helps ensure that you're analyzing only the valid sales data, leading to more accurate insights and better model performance.
#   -  Always validate whether negative or zero sales have any legitimate business meaning (such as returns, refunds, or zero sales weeks), but if not, they are typically treated as errors to be excluded.

# %%
traindf3 = traindf2.loc[traindf2['Weekly_Sales']>0] # outliers

# %%
len(traindf3)
# Out:
# 420212

# %%
421570 - 1358 # removed the outliers
# Out:
# 420212

# %%
traindf3.sort_values(by='Date')
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50      False        42.31
# 140804     15    21  2010-02-05       3253.19      False        19.83
# 140661     15    20  2010-02-05       4606.90      False        19.83
# 140518     15    19  2010-02-05       1381.40      False        19.83
# 140408     15    18  2010-02-05       2239.25      False        19.83
# ...       ...   ...         ...           ...        ...          ...
# 173673     18    52  2012-10-26       2226.10      False        56.09
# 342211     36    16  2012-10-26        564.50      False        74.39
# 390158     41    92  2012-10-26     131128.24      False        41.80
# 175485     18    81  2012-10-26      14036.52      False        56.09
# 421569     45    98  2012-10-26       1076.80      False        58.85
#
#         Fuel_Price         CPI  Unemployment _merge Type    Size
# 0            2.572  211.096358         8.106   both    A  151315
# 140804       2.954  131.527903         8.350   both    B  123737
# 140661       2.954  131.527903         8.350   both    B  123737
# 140518       2.954  131.527903         8.350   both    B  123737
# 140408       2.954  131.527903         8.350   both    B  123737
# ...            ...         ...           ...    ...  ...     ...
# 173673       3.917  138.728161         8.243   both    B  120653
# 342211       3.494  222.113657         6.228   both    A   39910
# 390158       3.686  199.219532         6.195   both    A  196321
# 175485       3.917  138.728161         8.243   both    B  120653
# 421569       3.882  192.308899         8.667   both    B  118221
#
# [420212 rows x 12 columns]

# %%
traindf3['Type'].unique() # store varities
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %% [markdown]
# # Now lets visualize the data

# %%
import matplotlib.pyplot as plt
import numpy as np

# creating dataset
data = traindf3['Type'].value_counts()

# creating plot
fig, ax = plt.subplots()
plt.pie(data, labels=data.index,autopct='%.0f%%')
ax.set_title('Which type of stores has more sales')

# show plot
plt.show()

# %%
traindf3['year'] = pd.DatetimeIndex(traindf3['Date']).year # sepearating year data
traindf3['month'] = pd.DatetimeIndex(traindf3['Date']).month  # Separating month data
traindf3['day'] = pd.DatetimeIndex(traindf3['Date']).day  # Separating day data
# Out:
# /tmp/ipykernel_36149/3253954075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf3['year'] = pd.DatetimeIndex(traindf3['Date']).year # sepearating year data
# /tmp/ipykernel_36149/3253954075.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf3['month'] = pd.DatetimeIndex(traindf3['Date']).month  # Separating month data
# /tmp/ipykernel_36149/3253954075.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf3['day'] = pd.DatetimeIndex(traindf3['Date']).day  # Separating day data

# %%
traindf3
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50      False        42.31
# 1           1     1  2010-02-12      46039.49       True        38.51
# 2           1     1  2010-02-19      41595.55      False        39.93
# 3           1     1  2010-02-26      19403.54      False        46.63
# 4           1     1  2010-03-05      21827.90      False        46.50
# ...       ...   ...         ...           ...        ...          ...
# 421565     45    98  2012-09-28        508.37      False        64.88
# 421566     45    98  2012-10-05        628.10      False        64.89
# 421567     45    98  2012-10-12       1061.02      False        54.47
# 421568     45    98  2012-10-19        760.01      False        56.47
# 421569     45    98  2012-10-26       1076.80      False        58.85
#
#         Fuel_Price         CPI  Unemployment _merge Type    Size  year  month  \
# 0            2.572  211.096358         8.106   both    A  151315  2010      2
# 1            2.548  211.242170         8.106   both    A  151315  2010      2
# 2            2.514  211.289143         8.106   both    A  151315  2010      2
# 3            2.561  211.319643         8.106   both    A  151315  2010      2
# 4            2.625  211.350143         8.106   both    A  151315  2010      3
# ...            ...         ...           ...    ...  ...     ...   ...    ...
# 421565       3.997  192.013558         8.684   both    B  118221  2012      9
# 421566       3.985  192.170412         8.667   both    B  118221  2012     10
# 421567       4.000  192.327265         8.667   both    B  118221  2012     10
# 421568       3.969  192.330854         8.667   both    B  118221  2012     10
# 421569       3.882  192.308899         8.667   both    B  118221  2012     10
#
#         day
# 0         5
# 1        12
# 2        19
# 3        26
# 4         5
# ...     ...
# 421565   28
# 421566    5
# 421567   12
# 421568   19
# 421569   26
#
# [420212 rows x 15 columns]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
tips = traindf3
ax = sns.barplot(x='Store',y='Weekly_Sales',data=tips) # weekly sales vs store

# %%
# store vs unemployement
data = traindf3
sns.lineplot(x='Store',y='Unemployment',data=data)
plt.show()

# %%
# weekly sales vs department
data = traindf3
sns.pointplot(x='Dept',
             y='Weekly_Sales',
             data=data)
sns.set(rc = {'figure.figsize':(25,8)})
plt.show()

# %%
month_wise_sales = pd.pivot_table(traindf3,values='Weekly_Sales',columns='year',index='month')
month_wise_sales.plot()
# Out:
# <Axes: xlabel='month'>

# %%
# Label encoding for Holiday column and Type
from sklearn import preprocessing

# label_encoder object knows how to understand word labels
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'
traindf3['IsHoliday'] = label_encoder.fit_transform(traindf3['IsHoliday'])
traindf3['Type'] = label_encoder.fit_transform(traindf3['Type'])

traindf3
# Out:
# /tmp/ipykernel_36149/279796669.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf3['IsHoliday'] = label_encoder.fit_transform(traindf3['IsHoliday'])
# /tmp/ipykernel_36149/279796669.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf3['Type'] = label_encoder.fit_transform(traindf3['Type'])
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50          0        42.31
# 1           1     1  2010-02-12      46039.49          1        38.51
# 2           1     1  2010-02-19      41595.55          0        39.93
# 3           1     1  2010-02-26      19403.54          0        46.63
# 4           1     1  2010-03-05      21827.90          0        46.50
# ...       ...   ...         ...           ...        ...          ...
# 421565     45    98  2012-09-28        508.37          0        64.88
# 421566     45    98  2012-10-05        628.10          0        64.89
# 421567     45    98  2012-10-12       1061.02          0        54.47
# 421568     45    98  2012-10-19        760.01          0        56.47
# 421569     45    98  2012-10-26       1076.80          0        58.85
#
#         Fuel_Price         CPI  Unemployment _merge  Type    Size  year  \
# 0            2.572  211.096358         8.106   both     0  151315  2010
# 1            2.548  211.242170         8.106   both     0  151315  2010
# 2            2.514  211.289143         8.106   both     0  151315  2010
# 3            2.561  211.319643         8.106   both     0  151315  2010
# 4            2.625  211.350143         8.106   both     0  151315  2010
# ...            ...         ...           ...    ...   ...     ...   ...
# 421565       3.997  192.013558         8.684   both     1  118221  2012
# 421566       3.985  192.170412         8.667   both     1  118221  2012
# 421567       4.000  192.327265         8.667   both     1  118221  2012
# 421568       3.969  192.330854         8.667   both     1  118221  2012
# 421569       3.882  192.308899         8.667   both     1  118221  2012
#
#         month  day
# 0           2    5
# 1           2   12
# 2           2   19
# 3           2   26
# 4           3    5
# ...       ...  ...
# 421565      9   28
# 421566     10    5
# 421567     10   12
# 421568     10   19
# 421569     10   26
#
# [420212 rows x 15 columns]

# %% [markdown]
# # Feature Importance Test using various techniques

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
Features = traindf3.drop(['Weekly_Sales','Date','_merge'],axis=1)
Target = traindf3['Weekly_Sales']

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(Features, Target)
# Out:
# RandomForestRegressor()

# %%
Features
# Out:
#         Store  Dept  IsHoliday  Temperature  Fuel_Price         CPI  \
# 0           1     1          0        42.31       2.572  211.096358
# 1           1     1          1        38.51       2.548  211.242170
# 2           1     1          0        39.93       2.514  211.289143
# 3           1     1          0        46.63       2.561  211.319643
# 4           1     1          0        46.50       2.625  211.350143
# ...       ...   ...        ...          ...         ...         ...
# 421565     45    98          0        64.88       3.997  192.013558
# 421566     45    98          0        64.89       3.985  192.170412
# 421567     45    98          0        54.47       4.000  192.327265
# 421568     45    98          0        56.47       3.969  192.330854
# 421569     45    98          0        58.85       3.882  192.308899
#
#         Unemployment  Type    Size  year  month  day
# 0              8.106     0  151315  2010      2    5
# 1              8.106     0  151315  2010      2   12
# 2              8.106     0  151315  2010      2   19
# 3              8.106     0  151315  2010      2   26
# 4              8.106     0  151315  2010      3    5
# ...              ...   ...     ...   ...    ...  ...
# 421565         8.684     1  118221  2012      9   28
# 421566         8.667     1  118221  2012     10    5
# 421567         8.667     1  118221  2012     10   12
# 421568         8.667     1  118221  2012     10   19
# 421569         8.667     1  118221  2012     10   26
#
# [420212 rows x 12 columns]

# %%
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(7)
plt.barh(Features.columns, rf.feature_importances_)
# Out:
# <BarContainer object of 12 artists>

# %%
F = Features.drop(['IsHoliday','year'],axis=1) # dropping less important features

# %%
F
# Out:
#         Store  Dept  Temperature  Fuel_Price         CPI  Unemployment  Type  \
# 0           1     1        42.31       2.572  211.096358         8.106     0
# 1           1     1        38.51       2.548  211.242170         8.106     0
# 2           1     1        39.93       2.514  211.289143         8.106     0
# 3           1     1        46.63       2.561  211.319643         8.106     0
# 4           1     1        46.50       2.625  211.350143         8.106     0
# ...       ...   ...          ...         ...         ...           ...   ...
# 421565     45    98        64.88       3.997  192.013558         8.684     1
# 421566     45    98        64.89       3.985  192.170412         8.667     1
# 421567     45    98        54.47       4.000  192.327265         8.667     1
# 421568     45    98        56.47       3.969  192.330854         8.667     1
# 421569     45    98        58.85       3.882  192.308899         8.667     1
#
#           Size  month  day
# 0       151315      2    5
# 1       151315      2   12
# 2       151315      2   19
# 3       151315      2   26
# 4       151315      3    5
# ...        ...    ...  ...
# 421565  118221      9   28
# 421566  118221     10    5
# 421567  118221     10   12
# 421568  118221     10   19
# 421569  118221     10   26
#
# [420212 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(F, Target, test_size=0.25,random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score,mean_squared_error
from math import sqrt

# %%
DTRmodel = DecisionTreeRegressor(max_depth=3, random_state=0)
DTRmodel.fit(x_train,y_train)
y_pred = DTRmodel.predict(x_test)

# %%
print("R2 score : ",r2_score(y_test,y_pred))
print("MSE score : ",mean_squared_error(y_test,y_pred))
print("RMSE : ",sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score :  0.3796166061691
# MSE score :  323184793.8287025
# RMSE :  17977.34112233237

# %%
rf1 = RandomForestRegressor(n_estimators=50, random_state=42, n_jobs=1, max_depth=35,
                           max_features='sqrt',min_samples_split=10)

rf1.fit(x_train,y_train)
y_pred1 = rf1.predict(x_test)

# %%
print("R2 score : ",r2_score(y_test,y_pred1))
print("MSE score : ",mean_squared_error(y_test,y_pred1))
print("RMSE : ",sqrt(mean_squared_error(y_test,y_pred1)))
# Out:
# R2 score :  0.8627233236773484
# MSE score :  71513413.76316498
# RMSE :  8456.560397890207

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred2 = model.predict(x_test)

# %%
print("R2 score : ",r2_score(y_test,y_pred2))
print("MSE score : ",mean_squared_error(y_test,y_pred2))
print("RMSE : ",sqrt(mean_squared_error(y_test,y_pred2)))
# Out:
# R2 score :  0.9404070945004744
# MSE score :  31044546.112991456
# RMSE :  5571.763285800237
